# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#%matplotlib inline
sns.set_theme()
pd.options.display.float_format = '{:.2f}'.format


df = pd.read_csv('dfClean.csv')
df.head(10)
# Out:
#    precio         ubicacion  dorm  ban  sup  precio/m2  sup/ban
# 0   40000       San Vicente     1    1   45     888.89    45.00
# 1   67000     Nueva Córdoba     1    1   45    1488.89    45.00
# 2   78800  Chateau Carreras     1    1   47    1676.60    47.00
# 3  105000       General Paz     2    2   75    1400.00    37.50
# 4   75000       General Paz     2    2   65    1153.85    32.50
# 5   65000     Nueva Córdoba     1    1   49    1326.53    49.00
# 6  120000     Nueva Córdoba     2    2   97    1237.11    48.50
# 7  160000     Nueva Córdoba     2    1   86    1860.47    86.00
# 8   46000     Nueva Córdoba     1    1   44    1045.45    44.00
# 9   49500            Centro     1    1   45    1100.00    45.00

# %%
#define dimensions of subplots (rows, columns)
fig, axes = plt.subplots(1, 2)

#create chart in each subplot
sns.histplot(data=df, x='precio',kde=True, ax=axes[0])
sns.histplot(data=df, x='precio/m2',kde=True, ax=axes[1])
plt.show()

# %%
sns.displot(x='precio', data=df, kde=True)
